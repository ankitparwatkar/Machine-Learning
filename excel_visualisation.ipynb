# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\ankit\Downloads\basketball_height (1).xlsx")

# %%
df.head()
# Out:
#    SNO       player_name team_abbreviation  age  player_height
# 0    1  Gaylon Nickerson               WAS   28         190.50
# 1    2      George Lynch               VAN   26         203.20
# 2    3    George McCloud               LAL   30         203.20
# 3    4      George Zidek               DEN   23         213.36
# 4    5    Gerald Wilkins               ORL   33         198.12

# %%
df.tail()
# Out:
#     SNO       player_name team_abbreviation  age  player_height
# 49   50   Jerome Williams               DET   24         205.74
# 50   51  Erick Strickland               DAL   30         255.00
# 51   52     Ervin Johnson               DEN   35         260.00
# 52   53        Evric Gray               NJN   22         245.00
# 53   54    Felton Spencer               GSW   22         275.00

# %%
df.describe()
# Out:
#              SNO        age  player_height
# count  54.000000  54.000000      54.000000
# mean   27.500000  28.203704     206.374074
# std    15.732133   4.149924      18.361112
# min     1.000000  21.000000     182.880000
# 25%    14.250000  25.000000     193.040000
# 50%    27.500000  28.000000     203.200000
# 75%    40.750000  31.000000     210.820000
# max    54.000000  39.000000     275.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SNO                54 non-null     int64
#  1   player_name        54 non-null     object
#  2   team_abbreviation  54 non-null     object
#  3   age                54 non-null     int64
#  4   player_height      54 non-null     float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 2.2+ KB

# %%
df.isnull().sum()
# Out:
# SNO                  0
# player_name          0
# team_abbreviation    0
# age                  0
# player_height        0
# dtype: int64

# %%
df.isna().sum()
# Out:
# SNO                  0
# player_name          0
# team_abbreviation    0
# age                  0
# player_height        0
# dtype: int64

# %%
df.age.mean()
# Out:
# np.float64(206.3740740740741)

# %%
df.player_height.mean()
# Out:
# np.float64(206.3740740740741)

# %%
df.age.mode()
# Out:
# 0    24
# Name: age, dtype: int64

# %%
df.player_height.mode()
# Out:
# 0    203.2
# Name: player_height, dtype: float64

# %%
df.age.median()
# Out:
# np.float64(28.0)

# %%
df.player_height.median()
# Out:
# np.float64(203.2)

# %%
df.age.std()
# Out:
# np.float64(4.149924435000286)

# %%
df.player_height.std()
# Out:
# np.float64(18.361111747336626)

# %%
df.age.var()   # variance
# Out:
# np.float64(17.22187281621244)

# %%
df.player_height.var()   # variance
# Out:
# np.float64(337.1304245981831)

# %%
df.age.max()
# Out:
# np.int64(39)

# %%
df.player_height.max()
# Out:
# np.float64(275.0)

# %%
df.age.min()
# Out:
# np.int64(21)

# %%
df.player_height.min()
# Out:
# np.float64(182.88)

# %%
df.age.skew()   # skewness
# Out:
# np.float64(0.44214021171592033)

# %%
df.player_height.skew()   # skewness
# Out:
# np.float64(1.8295118381176567)

# %%
df.age.quantile(0.25)   # 1st quartile
# Out:
# np.float64(25.0)

# %%
df.age.quantile(0.50)   # 2nd quartile
# Out:
# np.float64(28.0)

# %%
df.age.quantile(0.75)   # 3rd quartile
# Out:
# np.float64(31.0)

# %%
df.player_height.quantile(0.25)   # 1st quartile
# Out:
# np.float64(193.04)

# %%
df.player_height.quantile(0.50)   # 2nd quartile
# Out:
# np.float64(203.2)

# %%
df.player_height.quantile(0.75)   # 3rd quartile
# Out:
# np.float64(210.82)

# %%
df.outlier=(df.age.quantile(0.75) - df.age.quantile(0.25))
print(df.outlier) # IQR age
# Out:
# 6.0

# %%
df.outlier=(df.player_height.quantile(0.75) - df.player_height.quantile(0.25))
print(df.outlier) # IQR player_height
# Out:
# 17.78

# %%
df.age.plot(kind='hist', bins=10, grid=True, title='Histogram of Age', legend=True, label='Age')
# Out:
# <Axes: title={'center': 'Histogram of Age'}, ylabel='Frequency'>

# %%
df.player_height.plot(kind='hist', bins=10, grid=True, title='Histogram of Player Height', legend=True, label='Player Height')
# Out:
# <Axes: title={'center': 'Histogram of Player Height'}, ylabel='Frequency'>

# %%
df.age.plot(kind='box', grid=True, title='Boxplot of Age', legend=True, label='Age')
# Out:
# <Axes: title={'center': 'Boxplot of Age'}>

# %%
df.player_height.plot(kind='box', grid=True, title='Boxplot of Player Height', legend=True, label='Player Height')
# Out:
# <Axes: title={'center': 'Boxplot of Player Height'}>

# %%
df.plot(kind='scatter', x='age', y='player_height', grid=True, title='Scatter plot of Age and Player Height', legend=True, label='Age')
# Out:
# <Axes: title={'center': 'Scatter plot of Age and Player Height'}, xlabel='age', ylabel='player_height'>

# %%
df.plot(kind='line', y='age', grid=True, title='Violin plot of Age', legend=True, label='Age')
# Out:
# <Axes: title={'center': 'Violin plot of Age'}>

# %%
df.plot(kind='line', y='player_height', grid=True, title='Violin plot of Player Height', legend=True, label='Player Height')
# Out:
# <Axes: title={'center': 'Violin plot of Player Height'}>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.regplot(x='age', y='player_height', data=df,)
# Out:
# <Axes: xlabel='age', ylabel='player_height'>

# %%
sns.boxplot(x='age', y='player_height', data=df)
# Out:
# <Axes: xlabel='age', ylabel='player_height'>

# %%
sns.pairplot(data=df)

# %%
sns.violinplot(x='age', y='player_height', data=df)
plt.title('Violin plot of Age and Player Height')
plt.show()

# %%
sns.boxenplot(data=df)
# Out:
# <Axes: >
